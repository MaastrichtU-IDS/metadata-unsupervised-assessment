# %%
get_ipython().magic('matplotlib inline')

from __future__ import print_function
from time import time
import os
import logging
import csv
import numpy as np
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

import numpy as np

n_top_words=30
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

csv_file_object = csv.reader(open('data_description.csv', 'r'))

data = []
for row in csv_file_object:
    data.append(row)
data = np.array(data)
#data1 = [word for word in data if word not in stopwords.words('english')]

print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=20,
                                   stop_words='english')

tfidf = tfidf_vectorizer.fit_transform(data.ravel())



model = NMF(n_components=10, init='random', random_state=0)
W = model.fit_transform(tfidf)
H = model.components_
tfidf_feature_names = tfidf_vectorizer.get_feature_names()
print_top_words(model, tfidf_feature_names, n_top_words)
# Out:
# Extracting tf-idf features for NMF...
# C:\Users\stuti.nayak\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1059: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# Topic #0: extracted using total samples rna qiagen ml min manufacturer kit dna cells ca age 10
# Topic #1: age ml kit total rna using samples qiagen min manufacturer extracted dna cells ca 10
# Topic #2: total using samples rna qiagen ml min manufacturer kit extracted dna cells ca age 10
# Topic #3: age manufacturer using total samples rna qiagen ml min kit extracted dna cells ca 10
# Topic #4: kit using rna qiagen cells total samples ml min manufacturer extracted dna ca age 10
# Topic #5: ml ca cells using total samples rna qiagen min manufacturer kit extracted dna age 10
# Topic #6: qiagen using total samples rna ml min manufacturer kit extracted dna cells ca age 10
# Topic #7: 10 kit using total samples rna qiagen ml min manufacturer extracted dna cells ca age
# Topic #8: manufacturer using rna total samples qiagen ml min kit extracted dna cells ca age 10
# Topic #9: samples using total rna qiagen ml min manufacturer kit extracted dna cells ca age 10
# Topic #10: rna using cells total samples qiagen ml min manufacturer kit extracted dna ca age 10
# Topic #11: using ca rna total samples qiagen ml min manufacturer kit extracted dna cells age 10
# Topic #12: cells qiagen using total samples rna ml min manufacturer kit extracted dna ca age 10
# Topic #13: dna ca extracted cells using total samples rna qiagen ml min manufacturer kit age 10
# Topic #14: min using ml rna 10 kit samples total qiagen manufacturer extracted dna cells ca age

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-82169532ba9b> in <module>()
#       4                                    stop_words='english')
#       5
# ----> 6 tfidf = tfidf_vectorizer.fit_transform(data.ravel())
#
# NameError: name 'data' is not defined

# %%
get_ipython().magic('matplotlib inline')

from __future__ import print_function
from time import time
import os
import logging
import csv
import numpy as np
import pandas as pd
from nltk import word_tokenize
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

import numpy as np

n_top_words=30
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

csv_file_object = csv.reader(open('sample type.csv', 'r'))

data = []
for row in csv_file_object:
    data.append(row)
data = np.array(data)
#data1 = [word for word in data if word not in stopwords.words('english')]

print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                   max_features=15,
                                   stop_words='english')

tfidf = tfidf_vectorizer.fit_transform(data.ravel())
print(tfidf)
# Out:
# Extracting tf-idf features for NMF...
#   (0, 13)	0.8941434610168543
#   (0, 2)	0.44778060601236536
#   (2, 12)	1.0
#   (3, 13)	0.9114946004607756
#   (3, 12)	0.41131203888392454
#   (5, 12)	1.0
#   (7, 13)	1.0
#   (12, 12)	1.0
#   (14, 12)	1.0
#   (15, 2)	0.6921119581806848
#   (15, 6)	0.7217901615728064
#   (18, 12)	1.0
#   (19, 2)	0.27660329984157994
#   (19, 6)	0.28846422623448487
#   (19, 7)	0.2947414725046075
#   (19, 14)	0.2947414725046075
#   (19, 3)	0.2947414725046075
#   (19, 5)	0.2947414725046075
#   (19, 4)	0.2947414725046075
#   (19, 0)	0.3994019222628898
#   (19, 10)	0.2947414725046075
#   (19, 8)	0.3994019222628898
#   (20, 2)	0.27660329984157994
#   (20, 6)	0.28846422623448487
#   (20, 7)	0.2947414725046075
#   :	:
#   (50, 4)	0.2947414725046075
#   (50, 0)	0.3994019222628898
#   (50, 10)	0.2947414725046075
#   (50, 9)	0.3994019222628898
#   (51, 2)	0.27660329984157994
#   (51, 6)	0.28846422623448487
#   (51, 7)	0.2947414725046075
#   (51, 14)	0.2947414725046075
#   (51, 3)	0.2947414725046075
#   (51, 5)	0.2947414725046075
#   (51, 4)	0.2947414725046075
#   (51, 10)	0.2947414725046075
#   (51, 8)	0.3994019222628898
#   (51, 1)	0.3994019222628898
#   (52, 2)	0.27660329984157994
#   (52, 6)	0.28846422623448487
#   (52, 7)	0.2947414725046075
#   (52, 14)	0.2947414725046075
#   (52, 3)	0.2947414725046075
#   (52, 5)	0.2947414725046075
#   (52, 4)	0.2947414725046075
#   (52, 10)	0.2947414725046075
#   (52, 9)	0.3994019222628898
#   (52, 1)	0.3994019222628898
#   (56, 13)	1.0
# C:\Users\stuti.nayak\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1059: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
